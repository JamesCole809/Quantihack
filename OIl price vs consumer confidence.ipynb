# %%
# Out:
# Pulling data for Correlation 1...
# Correlation 1 — R²=0.367, p=0.0000, corr=-0.606
#
# Pulling data for Correlation 2...
# Correlation 2 — R²=0.115, p=0.0011, corr=0.339
#
# Pulling data for Correlation 3...
# Correlation 3 — R²=0.042, p=0.0006, corr=0.204
#
# ...
# ALTERNATIVE DATA ALPHA — ALL CORRELATIONS SUMMARY
# ...
#
# 1. Oil Price → Consumer Confidence (3 month lag)
#    R²=0.367 | p=0.0000 | SIGNIFICANT
#
# 2. Unemployment → S&P 500 (2 month lag)
#    R²=0.115 | p=0.0011 | SIGNIFICANT
#
# 3. Fed Rate → House Prices (6 month lag)
#    R²=0.042 | p=0.0006 | SIGNIFICANT
# ...
